# %% [markdown]
# # WATER

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [10,25,50,75,100,150]
y_fps = [6.2492,2.2182,7.17E-01,5.56E-01,5.52E-01,5.52E-01]
error_fps=[0.947612368,0.1300276894,0.06590719232,0.007677043702,0.000228035085,0.000044721359]


y_RD = [8.402,2.869833333,9.48E-01,6.53E-01,5.35E-01,5.52E-01]
error_RD=[2.482194191,1.247735295,0.3225969524,0.09231582024,0.08670780818,0.0005085928299]


y_CUR = [6.273,1.932,6.03E-01,5.52E-01,5.52E-01,5.52E-01]
error_CUR=[0,0,0,0,0,0]



plt.errorbar(x,y_fps,error_fps,linestyle='None', marker='^')
plt.errorbar(x,y_RD,error_RD,linestyle='None', marker='^')
plt.errorbar(x,y_CUR,error_CUR,linestyle='None', marker='^')



plt.show()

# %%
x = [10,25,50,75,100,150]
log_y_fps = [0.791917148,0.3453766963,-0.1461304203,-0.2518600209,-0.2580766875,-0.2580451884]
log_error_fps=[0.06474404958,0.02631900227,0.03918381968,0.005938459964,0.0001794498237,0.00003518203012]


log_y_RD = [0.9101506596,0.4223533263,-0.04343758676,-0.1887574585,-0.2776624509,-0.2584021418]
log_error_RD=[0.1191009479,0.1947825966,0.1432009983,0.05921893344,0.08055033871,0.000400684833]


log_y_CUR = [0.7974752875,0.2860071221,-0.2193946942,-0.2583757425,-0.2581396059,-0.2579822529]
error_CUR=[0,0,0,0,0,0]

# %%
plt.xlabel('Number of Sampled environments')
plt.ylabel('average RMSE (%)')

XTICKS=[25,50,75,100,125,150]

plt.errorbar(x,y_fps,error_fps,linestyle='None', marker='x',label='FPS', zorder=2)
plt.errorbar(x,y_RD,error_RD,linestyle='None', marker='_',label='RANDOM' ,zorder=1)
plt.errorbar(x,y_CUR,error_CUR,linestyle='None', marker='.',label='CUR' ,zorder=3)

plt.legend(loc="upper right")
plt.yscale("log")
plt.xticks(XTICKS)
# Out:
# ([<matplotlib.axis.XTick at 0x7d875a046320>,
# ...
#  [Text(25, 0, '25'),
#   Text(50, 0, '50'),
#   Text(75, 0, '75'),
#   Text(100, 0, '100'),
#   Text(125, 0, '125'),
#   Text(150, 0, '150')])

# %% [markdown]
# # DIF

# %%
X=[50,100,200,300,400,500]

L_Y_FPS = [0.6759154437,  0.5413831409  ,  0.4130795241  ,  0.359217884  ,  0.3186054391  ,  0.2977772006  ]
L_E_FPS= [0.009477511035,  0.02008678265  ,  0.009655788463  ,  0.007247802888  ,  0.006781656902  ,  0.005427201118  ]

dif_FPS=[4.734,3.449666667,2.576833333,2.273833333,2.028,1.984]
dif_FPS_error=[0.09483881062,0.1632343918,0.0598946297,0.04688461013,0.03970222496,0.02230694959]

dif_RD=[6.776833333,4.721,3.1455,2.699833333,2.437333333,2.252333333]
dif_RD_error=[0.8331646696,0.677771938,0.1806064783,0.09780678231,0.05984201423,0.07525334987]

dif_CUR=[4.891,3.651,2.681,2.305,2.125,2.086]


L_Y_RD = [0.8283186454, 0.6706890277,  0.4970943586  ,  0.4310989669  ,  0.3868081946  ,0.3524315998]
L_E_RD=[0.05301571719, 0.05746440615,  0.02490187874  ,  0.01575854402  ,  0.01049019671  ,0.0144601731]


L_Y_CUR = [0.6893976628, 0.5624118329 ,0.428296814 ,0.3626709297 ,0.3273589344 ,0.3193143041]
error_CUR_1=[0,0,0,0,0,0]

# %%
plt.xlabel('Number of Sampled environments')
plt.ylabel('log average RMSE (%)')

ticking=[100,200,300,400,500]

plt.errorbar(X,dif_FPS,dif_FPS_error,linestyle='None', marker='x',label='FPS', zorder=2)
plt.errorbar(X,dif_RD,dif_RD_error,linestyle='None', marker='_',label='RANDOM' ,zorder=1)
plt.errorbar(X,dif_CUR,error_CUR_1,linestyle='None', marker='.',label='CUR' ,zorder=3)

plt.legend(loc="upper right")
plt.yscale("log")
plt.xticks(ticking)
# Out:
# ([<matplotlib.axis.XTick at 0x7d875977a4a0>,
# ...
#  [Text(100, 0, '100'),
#   Text(200, 0, '200'),
#   Text(300, 0, '300'),
#   Text(400, 0, '400'),
#   Text(500, 0, '500')])

# %% [markdown]
# # Si

# %%
x_2=[10,25,50,75,100]

L_F=[0.08841190228,0.0108915327,0.0009400968963,-0.027783929,-0.06295972034]
L_F_E=[0.002894478625,0.001389572131,0.003941866349,0.003972791504,0.004166886791]

L_R=[0.1819010772,0.0734747532,-0.005526174394,-0.03420859048,-0.06227860614]
L_R_E=[0.06726573245,0.03999672866,0.01160317524,0.007420920988,0.01054553666]

L_C=[0.1586639808,0.01410032152,0.00560944536,-0.01569776802,-0.003619686767]
L_C_E=[0,0,0,0,0]


sil_FPS=[1.234166667,1.031333333,9.92E-01,9.37E-01,8.69E-01]
sil_FPS_error=[0.02175699121,0.01482790163,0.0254209887,0.007966429564,0.01143987179]

sil_RD=[1.536666667,1.1885,9.88E-01,9.24E-01,8.67E-01]
sil_RD_error=[0.2660095236,0.1083452814,0.02641066073,0.01580906913,0.0207332985]

sil_CUR=[1.441,1.033,1.013,9.65E-01,9.92E-01]

# %%
plt.xlabel('Number of Sampled environments')
plt.ylabel('average RMSE (%)')

tok=[25,50,75,100]

plt.errorbar(x_2,sil_FPS,sil_FPS_error,linestyle='None', marker='x',label='FPS', zorder=2)
plt.errorbar(x_2,sil_RD,sil_RD_error,linestyle='None', marker='_',label='RANDOM' ,zorder=1)
plt.errorbar(x_2,sil_CUR,L_C_E,linestyle='None', marker='.',label='CUR' ,zorder=3)

plt.legend(loc="upper right")

plt.yscale("log")
plt.xticks(tok)
# Out:
# ([<matplotlib.axis.XTick at 0x7d8759cf21d0>,
# ...
#  [Text(25, 0, '25'),
#   Text(50, 0, '50'),
#   Text(75, 0, '75'),
#   Text(100, 0, '100')])

# %% [markdown]
# # LEARNING CURVES

# %%
X_SIL=[0.1,0.25,0.5,1]
Y_SIL_STDEV=[0.5007703732,0.01487839597,0.02619580119,1.58E-02]
Y_SIL=[10.07416667,2.248166667,1.0367,9.24E-01]

Y_Water=[1.61E+01,4.705166667,1.238,5.35E-01]
Y_Water_STDEV=[0.01505545305,0.05361871564,0.07147866815,8.67E-02]

Y_DIFF=[8.89E+00,7.388166667,6.933166667,6.78E+00]
Y_DIFF_STDEV=[1.03E+00,8.08E-01,8.05E-01,8.33E-01]


plt.xlabel('train fraction')
plt.ylabel('average RMSE (%)')

plt.errorbar(X_SIL,Y_DIFF,Y_DIFF_STDEV,marker='x',label='C7H10O2 ')
plt.errorbar(X_SIL,Y_Water,Y_Water_STDEV, marker='x',label='Water')
plt.errorbar(X_SIL,Y_SIL,Y_SIL_STDEV,  marker='x',label='Si')

plt.yscale("log")
plt.legend(loc="upper right")
